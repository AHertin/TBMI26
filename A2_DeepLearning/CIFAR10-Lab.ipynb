# %%
import os
import tensorflow as tf

# If there are multiple GPUs and we only want to use one/some, set the number in the visible device list.
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# This sets the GPU to allocate memory only as needed
physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) != 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# ### **1. Loading the dataset**
# This assignment will focus on the CIFAR10 dataset. This is a collection of small images in 10 classes such as cars, cats, birds, etc. You can find more information here: https://www.cs.toronto.edu/~kriz/cifar.html. We start by loading and examining the data.

# %%
import numpy as np
from tensorflow.keras.datasets import cifar10

(X_train, y_train), (X_test, y_test) = cifar10.load_data()

print("Shape of training data:")
print(X_train.shape)
print(y_train.shape)
print("Shape of test data:")
print(X_test.shape)
print(y_test.shape)
# Out:
# Shape of training data:
# (50000, 32, 32, 3)
# (50000, 1)
# Shape of test data:
# (10000, 32, 32, 3)
# (10000, 1)

# %% [markdown]
# #### **<span style="color:red">Question 1:</span>**
# The shape of X_train and X_test has 4 values. What do each of these represent?

# %% [markdown]
# ##### **Plotting some images**
# This plots a random selection of images from each class. Rerun the cell to see a different selection.

# %%
from Custom import PlotRandomFromEachClass

cifar_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
PlotRandomFromEachClass(X_train, y_train, 3, labels=cifar_labels)

# %% [markdown]
# ##### **Preparing the dataset**
# Just like the MNIST dataset we normalize the images to [0,1] and transform the class indices to one-hot encoded vectors.

# %%
from tensorflow.keras.utils import to_categorical

# Transform label indices to one-hot encoded vectors
y_train_c = to_categorical(y_train, num_classes=10)
y_test_c  = to_categorical(y_test , num_classes=10)

# Normalization of pixel values (to [0-1] range)
X_train = X_train.astype('float32') / 255
X_test  = X_test.astype('float32')  / 255

# %% [markdown]
# ### **2. Fully connected classifier**
# We will start by creating a fully connected classifier using the ```Dense``` layer. We give you the first layer that flattens the image features to a single vector. Add the remaining layers to the network.
#
# Consider what the size of the output must be and what activation function you should use in the output layer.

# %%
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Flatten

x_in = Input(shape=X_train.shape[1:])
x = Flatten()(x_in)

# === Add your code here ===
x = Dense(64, activation="softplus")(x)
x = Dense(128, activation="softplus")(x)
x = Dense(32, activation="softplus")(x)
x = Dense(10, activation="softmax")(x)
# ==========================

model = Model(inputs=x_in, outputs=x)

# Now we build the model using Stochastic Gradient Descent with Nesterov momentum. We use accuracy as the metric.
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])
model.summary(100)
# Out:
# Model: "model"
# ____________________________________________________________________________________________________
# Layer (type)                                 Output Shape                            Param #
# ====================================================================================================
# input_1 (InputLayer)                         [(None, 32, 32, 3)]                     0
# ____________________________________________________________________________________________________
# flatten (Flatten)                            (None, 3072)                            0
# ____________________________________________________________________________________________________
# dense (Dense)                                (None, 64)                              196672
# ____________________________________________________________________________________________________
# dense_1 (Dense)                              (None, 128)                             8320
# ____________________________________________________________________________________________________
# dense_2 (Dense)                              (None, 32)                              4128
# ____________________________________________________________________________________________________
# dense_3 (Dense)                              (None, 10)                              330
# ====================================================================================================
# Total params: 209,450
# Trainable params: 209,450
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %% [markdown]
# ##### **Training the model**
# In order to show the differences between models in the first parts of the assignment, we will restrict the training to the following command using 15 epochs, batch size 32, and 20% validation data. From section 5 and forward you can change this as you please to increase the accuracy, but for now stick with this command.

# %%
history = model.fit(X_train,y_train_c, epochs=15, batch_size=32, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.8959 - accuracy: 0.3078 - val_loss: 1.7331 - val_accuracy: 0.3853
# Epoch 2/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.6923 - accuracy: 0.3908 - val_loss: 1.7288 - val_accuracy: 0.3944
# Epoch 3/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.6113 - accuracy: 0.4243 - val_loss: 1.6605 - val_accuracy: 0.3986
# Epoch 4/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.5479 - accuracy: 0.4430 - val_loss: 1.5654 - val_accuracy: 0.4425
# Epoch 5/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.4989 - accuracy: 0.4565 - val_loss: 1.5535 - val_accuracy: 0.4474
# Epoch 6/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.4631 - accuracy: 0.4751 - val_loss: 1.5179 - val_accuracy: 0.4537
# Epoch 7/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.4320 - accuracy: 0.4842 - val_loss: 1.5030 - val_accuracy: 0.4589
# Epoch 8/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.4023 - accuracy: 0.4950 - val_loss: 1.5245 - val_accuracy: 0.4642
# Epoch 9/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.3775 - accuracy: 0.5045 - val_loss: 1.4727 - val_accuracy: 0.4686
# Epoch 10/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.3534 - accuracy: 0.5122 - val_loss: 1.4668 - val_accuracy: 0.4839
# Epoch 11/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.3309 - accuracy: 0.5207 - val_loss: 1.4919 - val_accuracy: 0.4751
# Epoch 12/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.3115 - accuracy: 0.5278 - val_loss: 1.4587 - val_accuracy: 0.4868
# Epoch 13/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.2924 - accuracy: 0.5341 - val_loss: 1.4776 - val_accuracy: 0.4899
# Epoch 14/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.2727 - accuracy: 0.5401 - val_loss: 1.4478 - val_accuracy: 0.5022
# Epoch 15/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.2571 - accuracy: 0.5453 - val_loss: 1.4783 - val_accuracy: 0.4793

# %% [markdown]
# ##### **Evaluating the model**
# We use ```model.evaluate``` to get the loss and metric scores on the test data. To plot the results we give you a custom function that does the work for you.

# %%
score = model.evaluate(X_test, y_test_c, batch_size=128, verbose=0)

for i in range(len(score)):
    print("Test " + model.metrics_names[i] + " = %.3f" % score[i])
# Out:
# Test loss = 1.468
# Test accuracy = 0.480

# %%
from Custom import PlotModelEval

# Custom function for evaluating the model and plotting training history
PlotModelEval(model, history, X_test, y_test, cifar_labels)

# %% [markdown]
# #### **<span style="color:red">Question 2:</span>**
# Train a model that achieves above 45% accuracy on the test data. In the report, provide a (short) description of your model and show the evaluation image.

# %% [markdown]
# #### **<span style="color:red">Question 3:</span>**
# Compare this model to the one you used for the MNIST dataset in the first assignment, in terms of size and test accuracy. Why do you think this dataset is much harder to classify than the MNIST handwritten digits?

# %% [markdown]
# ### **3. CNN classifier**
# We will now move on to a network architecture that is more suited for this problem, the convolutional neural network. The new layers you will use are ```Conv2D``` and ```MaxPooling2D```, which you can find the documentation of here https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D and here https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D.

# %% [markdown]
# ##### **Creating the CNN model**
#
# A common way to build convolutional neural networks is to create blocks of layers of the form **[convolution - activation - pooling]**, and then stack several of these block to create the full convolution stack. This is often followed by a fully connected network to create the output classes. Use this recipe to build a CNN that acheives at least 62% accuracy on the test data.
#
# *Side note. Although this is a common way to build CNNs, it is be no means the only or even best way. It is a good starting point, but later in part 5 you might want to explore other architectures to acheive even better performance.*

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D

x_in = Input(shape=X_train.shape[1:])

# === Add your code here ===
x = Conv2D(32, (3, 3), activation="relu")(x_in)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Conv2D(64, (3, 3), activation="relu")(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Conv2D(128, (3, 3), activation="relu")(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Flatten()(x)
x = Dense(64, activation="softplus")(x)
x = Dense(32, activation="softplus")(x)
x = Dense(10, activation="softmax")(x)
# ==========================

model = Model(inputs=x_in, outputs=x)

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=sgd)
model.summary(100)
# Out:
# Model: "model_1"
# ____________________________________________________________________________________________________
# Layer (type)                                 Output Shape                            Param #
# ====================================================================================================
# input_2 (InputLayer)                         [(None, 32, 32, 3)]                     0
# ____________________________________________________________________________________________________
# conv2d (Conv2D)                              (None, 30, 30, 32)                      896
# ____________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)                 (None, 15, 15, 32)                      0
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                            (None, 13, 13, 64)                      18496
# ____________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)               (None, 6, 6, 64)                        0
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                            (None, 4, 4, 128)                       73856
# ____________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)               (None, 2, 2, 128)                       0
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)                          (None, 512)                             0
# ____________________________________________________________________________________________________
# dense_4 (Dense)                              (None, 64)                              32832
# ____________________________________________________________________________________________________
# dense_5 (Dense)                              (None, 32)                              2080
# ____________________________________________________________________________________________________
# dense_6 (Dense)                              (None, 10)                              330
# ====================================================================================================
# Total params: 128,490
# Trainable params: 128,490
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %% [markdown]
# ##### **Training the CNN**

# %%
history = model.fit(X_train, y_train_c, batch_size=32, epochs=15, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.8164 - accuracy: 0.3233 - val_loss: 1.4257 - val_accuracy: 0.4798
# Epoch 2/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.3229 - accuracy: 0.5249 - val_loss: 1.2223 - val_accuracy: 0.5637
# Epoch 3/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.1261 - accuracy: 0.6009 - val_loss: 1.0755 - val_accuracy: 0.6168
# Epoch 4/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 0.9970 - accuracy: 0.6463 - val_loss: 1.0142 - val_accuracy: 0.6482
# Epoch 5/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 0.8920 - accuracy: 0.6862 - val_loss: 1.0091 - val_accuracy: 0.6615
# Epoch 6/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 0.8141 - accuracy: 0.7108 - val_loss: 1.0170 - val_accuracy: 0.6547
# Epoch 7/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 0.7449 - accuracy: 0.7377 - val_loss: 0.9381 - val_accuracy: 0.6847
# Epoch 8/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 0.6827 - accuracy: 0.7585 - val_loss: 0.9726 - val_accuracy: 0.6824
# Epoch 9/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 0.6330 - accuracy: 0.7771 - val_loss: 0.9419 - val_accuracy: 0.6857
# Epoch 10/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 0.5809 - accuracy: 0.7906 - val_loss: 0.9934 - val_accuracy: 0.6899
# Epoch 11/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 0.5402 - accuracy: 0.8081 - val_loss: 1.0118 - val_accuracy: 0.6959
# Epoch 12/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 0.4945 - accuracy: 0.8235 - val_loss: 1.0349 - val_accuracy: 0.6906
# Epoch 13/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 0.4673 - accuracy: 0.8314 - val_loss: 1.1043 - val_accuracy: 0.6881
# Epoch 14/15
# 1250/1250 [==============================] - 3s 2ms/step - loss: 0.4341 - accuracy: 0.8459 - val_loss: 1.0546 - val_accuracy: 0.6907
# Epoch 15/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 0.4169 - accuracy: 0.8508 - val_loss: 1.1578 - val_accuracy: 0.6889

# %% [markdown]
# ##### **Evaluating the CNN**

# %%
score = model.evaluate(X_test, y_test_c, batch_size=128, verbose=0)

for i in range(len(score)):
    print("Test " + model.metrics_names[i] + " = %.3f" % score[i])
# Out:
# Test loss = 1.169
# Test accuracy = 0.686

# %%
PlotModelEval(model, history, X_test, y_test, cifar_labels)

# %% [markdown]
# #### **<span style="color:red">Question 4:</span>**
# Train a model that achieves at least 62% test accuracy. In the report, provide a (short) description of your model and show the evaluation image.

# %% [markdown]
# #### **<span style="color:red">Question 5:</span>**
# Compare this model with the previous fully connected model. You should find that this one is much more efficient, i.e. achieves higher accuracy with fewer parameters. Explain in your own words how this is possible.

# %% [markdown]
# ### **4. Regularization**

# %% [markdown]
# #### **4.1 Dropout**
# You have probably seen that your CNN model overfits the training data. One way to prevent this is to add ```Dropout``` layers to the model, that randomly "drops" hidden nodes each training-iteration by setting their output to zero. Thus the model cannot rely on a small set of very good hidden features, but must instead learns to use different sets of hidden features each time. Dropout layers are usually added after the pooling layers in the convolution part of the model, or after activations in the fully connected part of the model.
#
# *Side note. In the next assignment you will work with Ensemble models, a way to use the output from several individual models to achieve higher performance than each model can achieve on its own. One way to interpret Dropout is that each random selection of nodes is a separate model that is trained only on the current iteration. The final output is then the average of outputs from all the individual models. In other words, Dropout can be seen as a way to build ensembling directly into the network, without having to train several models explicitly.*
#
# Extend your previous model with the Dropout layer and test the new performance.

# %%
from tensorflow.keras.layers import Dropout

x_in = Input(shape=X_train.shape[1:])

# === Add your code here ===
x = Conv2D(32, (3, 3), activation="relu")(x_in)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Conv2D(64, (3, 3), activation="relu")(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Conv2D(128, (3, 3), activation="relu")(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Dropout(0.2)(x)
x = Flatten()(x)
x = Dense(64, activation="softplus")(x)
x = Dense(32, activation="softplus")(x)
x = Dense(10, activation="softmax")(x)
# ==========================

model = Model(inputs=x_in, outputs=x)

# Compile model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=sgd)
model.summary(100)
# Out:
# Model: "model_2"
# ____________________________________________________________________________________________________
# Layer (type)                                 Output Shape                            Param #
# ====================================================================================================
# input_3 (InputLayer)                         [(None, 32, 32, 3)]                     0
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                            (None, 30, 30, 32)                      896
# ____________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)               (None, 15, 15, 32)                      0
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                            (None, 13, 13, 64)                      18496
# ____________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)               (None, 6, 6, 64)                        0
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                            (None, 4, 4, 128)                       73856
# ____________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)               (None, 2, 2, 128)                       0
# ____________________________________________________________________________________________________
# dropout (Dropout)                            (None, 2, 2, 128)                       0
# ____________________________________________________________________________________________________
# flatten_2 (Flatten)                          (None, 512)                             0
# ____________________________________________________________________________________________________
# dense_7 (Dense)                              (None, 64)                              32832
# ____________________________________________________________________________________________________
# dense_8 (Dense)                              (None, 32)                              2080
# ____________________________________________________________________________________________________
# dense_9 (Dense)                              (None, 10)                              330
# ====================================================================================================
# Total params: 128,490
# Trainable params: 128,490
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
history = model.fit(X_train, y_train_c, batch_size=32, epochs=15, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.8934 - accuracy: 0.2889 - val_loss: 1.5299 - val_accuracy: 0.4361
# Epoch 2/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.4085 - accuracy: 0.4852 - val_loss: 1.2686 - val_accuracy: 0.5490
# Epoch 3/15
# 1250/1250 [==============================] - 3s 3ms/step - loss: 1.2151 - accuracy: 0.5640 - val_loss: 1.1064 - val_accuracy: 0.6124
# Epoch 4/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.0875 - accuracy: 0.6124 - val_loss: 1.1120 - val_accuracy: 0.6145
# Epoch 5/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 0.9937 - accuracy: 0.6470 - val_loss: 0.9528 - val_accuracy: 0.6712
# Epoch 6/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 0.9247 - accuracy: 0.6737 - val_loss: 0.9456 - val_accuracy: 0.6737
# Epoch 7/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 0.8567 - accuracy: 0.6974 - val_loss: 0.9103 - val_accuracy: 0.6816
# Epoch 8/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 0.8001 - accuracy: 0.7172 - val_loss: 0.8625 - val_accuracy: 0.6978
# Epoch 9/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 0.7542 - accuracy: 0.7353 - val_loss: 0.8833 - val_accuracy: 0.7008
# Epoch 10/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 0.7167 - accuracy: 0.7490 - val_loss: 0.8772 - val_accuracy: 0.7002
# Epoch 11/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 0.6753 - accuracy: 0.7633 - val_loss: 0.8625 - val_accuracy: 0.7052
# Epoch 12/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 0.6493 - accuracy: 0.7704 - val_loss: 0.8736 - val_accuracy: 0.7015
# Epoch 13/15
# 1250/1250 [==============================] - 4s 4ms/step - loss: 0.6107 - accuracy: 0.7857 - val_loss: 0.8427 - val_accuracy: 0.7155
# Epoch 14/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 0.5884 - accuracy: 0.7942 - val_loss: 0.8588 - val_accuracy: 0.7191
# Epoch 15/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 0.5630 - accuracy: 0.8014 - val_loss: 0.8537 - val_accuracy: 0.7141

# %%
score = model.evaluate(X_test, y_test_c, batch_size=128, verbose=0)

for i in range(len(score)):
    print("Test " + model.metrics_names[i] + " = %.3f" % score[i])
# Out:
# Test loss = 0.863
# Test accuracy = 0.716

# %%
PlotModelEval(model, history, X_test, y_test, cifar_labels)

# %% [markdown]
# #### **<span style="color:red">Question 6:</span>**
# Train the modified CNN-model. Save the evaluation image for the report.

# %% [markdown]
# #### **<span style="color:red">Question 7:</span>**
# Compare this model and the previous in terms of the training accuracy, validation accuracy, and test accuracy. Explain the similarities and differences (remember that the only difference between the models should be the addition of Dropout layers).
#
# Hint: what does the dropout layer do at test time?

# %% [markdown]
# #### **4.2 Batch normalization**
# The final layer we will explore is ```BatchNormalization```. As the name suggests, this layer normalizes the data in each batch to have a specific mean and standard deviation, which is learned during training. The reason for this is quite complicated (and still debated among the experts), but suffice to say that it helps the optimization converge faster which means we get higher performance in fewer epochs. The normalization is done separatly for each feature, i.e. the statistics are calculated accross the batch dimension of the input data. The equations for batch-normalizing one feature are the following, where $N$ is the batch size, $x$ the input features, and $y$ the normalized output features:
#
# $$ \mu = \frac{1}{N} \sum_{i=0}^{N}x_i,\;\;\;\; \sigma^2 = \frac{1}{N} \sum_{i=0}^{N}(x_i - \mu)^2 $$
#
# $$ \hat{x}_i = \frac{x_i - \mu}{\sqrt{\sigma^2 + \epsilon}} $$
#
# $$ y_i = \gamma \hat{x}_i + \beta $$
#
# At first glance this might look intimidating, but all it means is that we begin by scaling and shifting the data to have mean $\mu=0$ and standard deviation $\sigma=1$. After this we use the learnable parameters $\gamma$ and $\beta$ to decide the width and center of the final distribution. $\epsilon$ is a small constant value that prevents the denominator from being zero.
#
# In addition to learning the parameters $\gamma$ and $\beta$ by gradient decent just like the weights, Batch Normalization also keeps track of the running average of minibatch statistics $\mu$ and $\sigma$. These averages are used to normalize the test data. We can tune the rate at which the running averages are updated with the *momentum* parameter of the BatchNormalization layer. A large momentum means that the statistics converge more slowly and therefore requires more updates before it represents the data. A low momentum, on the other hand, adapts to the data more quickly but might lead to unstable behaviour if the latest minibatches are not representative of the whole dataset. For this test we recommend a momentum of 0.75, but you probably want to change this when you design a larger network in Section 5.
#
# The batch normalization layer should be added after the hidden layer linear transformation, but before the nonlinear activation. This means that we cannot specify the activation funciton in the ```Conv2D``` or ```Dense``` if we want to batch-normalize the output. We therefore need to use the ```Activation``` layer to add a separate activation to the network stack after batch normalization. For example, the convolution block will now look like **[conv - batchnorm - activation - pooling]**.
#
# Extend your previous model with batch normalization, both in the convolution and fully connected part of the model.

# %%
from tensorflow.keras.layers import BatchNormalization, Activation

x_in = Input(shape=X_train.shape[1:])

# === Add your code here ===
x = Conv2D(32, (3, 3))(x_in)
x = BatchNormalization(momentum=0.75)(x)
x = Activation("softplus")(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

x = Conv2D(64, (3, 3))(x)
x = BatchNormalization(momentum=0.75)(x)
x = Activation("softplus")(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

x = Conv2D(128, (3, 3))(x)
x = BatchNormalization(momentum=0.75)(x)
x = Activation("softplus")(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

x = Flatten()(x)

x = Dense(64)(x)
x = BatchNormalization(momentum=0.75)(x)
x = Activation("softplus")(x)

x = Dense(32)(x)
x = BatchNormalization(momentum=0.75)(x)
x = Activation("softplus")(x)

x = Dense(10, activation="softmax")(x)
# ==========================

model = Model(inputs=x_in, outputs=x)

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=sgd)
model.summary(100)
# Out:
# Model: "model_3"
# ____________________________________________________________________________________________________
# Layer (type)                                 Output Shape                            Param #
# ====================================================================================================
# input_4 (InputLayer)                         [(None, 32, 32, 3)]                     0
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                            (None, 30, 30, 32)                      896
# ____________________________________________________________________________________________________
# batch_normalization (BatchNormalization)     (None, 30, 30, 32)                      128
# ____________________________________________________________________________________________________
# activation (Activation)                      (None, 30, 30, 32)                      0
# ____________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)               (None, 15, 15, 32)                      0
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                            (None, 13, 13, 64)                      18496
# ____________________________________________________________________________________________________
# batch_normalization_1 (BatchNormalization)   (None, 13, 13, 64)                      256
# ____________________________________________________________________________________________________
# activation_1 (Activation)                    (None, 13, 13, 64)                      0
# ____________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)               (None, 6, 6, 64)                        0
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                            (None, 4, 4, 128)                       73856
# ____________________________________________________________________________________________________
# batch_normalization_2 (BatchNormalization)   (None, 4, 4, 128)                       512
# ____________________________________________________________________________________________________
# activation_2 (Activation)                    (None, 4, 4, 128)                       0
# ____________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)               (None, 2, 2, 128)                       0
# ____________________________________________________________________________________________________
# flatten_3 (Flatten)                          (None, 512)                             0
# ____________________________________________________________________________________________________
# dense_10 (Dense)                             (None, 64)                              32832
# ____________________________________________________________________________________________________
# batch_normalization_3 (BatchNormalization)   (None, 64)                              256
# ____________________________________________________________________________________________________
# activation_3 (Activation)                    (None, 64)                              0
# ____________________________________________________________________________________________________
# dense_11 (Dense)                             (None, 32)                              2080
# ____________________________________________________________________________________________________
# batch_normalization_4 (BatchNormalization)   (None, 32)                              128
# ____________________________________________________________________________________________________
# activation_4 (Activation)                    (None, 32)                              0
# ____________________________________________________________________________________________________
# dense_12 (Dense)                             (None, 10)                              330
# ====================================================================================================
# Total params: 129,770
# Trainable params: 129,130
# Non-trainable params: 640
# ____________________________________________________________________________________________________

# %%
history = model.fit(X_train, y_train_c, batch_size=32, epochs=15, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.3559 - accuracy: 0.5169 - val_loss: 1.2011 - val_accuracy: 0.5903
# Epoch 2/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.0323 - accuracy: 0.6382 - val_loss: 2.0765 - val_accuracy: 0.4079
# Epoch 3/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 0.8902 - accuracy: 0.6897 - val_loss: 0.8586 - val_accuracy: 0.7038
# Epoch 4/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.7997 - accuracy: 0.7211 - val_loss: 0.8427 - val_accuracy: 0.7100
# Epoch 5/15
# 1250/1250 [==============================] - 4s 4ms/step - loss: 0.7191 - accuracy: 0.7481 - val_loss: 0.8763 - val_accuracy: 0.6941
# Epoch 6/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.6544 - accuracy: 0.7712 - val_loss: 0.9675 - val_accuracy: 0.6765
# Epoch 7/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 0.6017 - accuracy: 0.7882 - val_loss: 0.9178 - val_accuracy: 0.6956
# Epoch 8/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.5502 - accuracy: 0.8059 - val_loss: 0.8208 - val_accuracy: 0.7297
# Epoch 9/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.5074 - accuracy: 0.8207 - val_loss: 0.9061 - val_accuracy: 0.7131
# Epoch 10/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.4687 - accuracy: 0.8357 - val_loss: 0.8518 - val_accuracy: 0.7282
# Epoch 11/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.4263 - accuracy: 0.8506 - val_loss: 0.8772 - val_accuracy: 0.7270
# Epoch 12/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.3978 - accuracy: 0.8585 - val_loss: 0.9033 - val_accuracy: 0.7247
# Epoch 13/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 0.3621 - accuracy: 0.8741 - val_loss: 1.0081 - val_accuracy: 0.7093
# Epoch 14/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.3313 - accuracy: 0.8833 - val_loss: 1.0250 - val_accuracy: 0.7211
# Epoch 15/15
# 1250/1250 [==============================] - 4s 4ms/step - loss: 0.3097 - accuracy: 0.8915 - val_loss: 1.0170 - val_accuracy: 0.7292

# %%
score = model.evaluate(X_test, y_test_c, batch_size=128, verbose=0)

for i in range(len(score)):
    print("Test " + model.metrics_names[i] + " = %.3f" % score[i])
# Out:
# Test loss = 1.049
# Test accuracy = 0.719

# %%
PlotModelEval(model, history, X_test, y_test, cifar_labels)

# %% [markdown]
# #### **<span style="color:red">Question 8:</span>**
# Train the model and save the evaluation image for the report.

# %% [markdown]
# #### **<span style="color:red">Question 9:</span>**
# When using BatchNorm one must take care to select a good minibatch size. Describe what problems might arise if the wrong minibatch size is used.
#
# You can reason about this given the description of BatchNorm above, or you can search for the information in other sources. Do not forget to provide links to the sources if you do!

# %% [markdown]
# ### **5. Putting it all together**
# We now want you to create your own model based on what you have learned. We want you to experiment and see what works and what doesn't, so don't go crazy with the number of epochs until you think you have something that works.
#
# To pass this assignment, we want you to acheive **75%** accuracy on the test data in no more than **25 epochs**. This is possible using the layers and techniques we have explored in this notebook, but you are free to use any other methods that we didn't cover. (You are obviously not allowed to cheat, for example by training on the test data.)

# %%
from tensorflow.keras.utils import plot_model

x_in = Input(shape=X_train.shape[1:])

# === Add your code here ===
x = Conv2D(32, (3, 3))(x_in)
x = BatchNormalization(momentum=0.95)(x)
x = Activation("relu")(x)

x = Conv2D(32, (3, 3))(x)
x = BatchNormalization(momentum=0.95)(x)
x = Activation("relu")(x)

x = MaxPooling2D(pool_size=(2, 2))(x)

x = Conv2D(64, (3, 3))(x)
x = BatchNormalization(momentum=0.95)(x)
x = Activation("relu")(x)

x = Conv2D(64, (3, 3))(x)
x = BatchNormalization(momentum=0.95)(x)
x = Activation("relu")(x)

x = MaxPooling2D(pool_size=(2, 2))(x)

x = Flatten()(x)

x = Dense(128)(x)
x = BatchNormalization(momentum=0.95)(x)
x = Activation("relu")(x)

x = Dense(10, activation="softmax")(x)
# ==========================

model = Model(inputs=x_in, outputs=x)

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=sgd)
model.summary(100)
plot_model(model, show_shapes=True, show_layer_names=False)
# Out:
# Model: "model_4"
# ____________________________________________________________________________________________________
# Layer (type)                                 Output Shape                            Param #
# ====================================================================================================
# input_5 (InputLayer)                         [(None, 32, 32, 3)]                     0
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                            (None, 30, 30, 32)                      896
# ____________________________________________________________________________________________________
# batch_normalization_5 (BatchNormalization)   (None, 30, 30, 32)                      128
# ____________________________________________________________________________________________________
# activation_5 (Activation)                    (None, 30, 30, 32)                      0
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)                           (None, 28, 28, 32)                      9248
# ____________________________________________________________________________________________________
# batch_normalization_6 (BatchNormalization)   (None, 28, 28, 32)                      128
# ____________________________________________________________________________________________________
# activation_6 (Activation)                    (None, 28, 28, 32)                      0
# ____________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)               (None, 14, 14, 32)                      0
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)                           (None, 12, 12, 64)                      18496
# ____________________________________________________________________________________________________
# batch_normalization_7 (BatchNormalization)   (None, 12, 12, 64)                      256
# ____________________________________________________________________________________________________
# activation_7 (Activation)                    (None, 12, 12, 64)                      0
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)                           (None, 10, 10, 64)                      36928
# ____________________________________________________________________________________________________
# batch_normalization_8 (BatchNormalization)   (None, 10, 10, 64)                      256
# ____________________________________________________________________________________________________
# activation_8 (Activation)                    (None, 10, 10, 64)                      0
# ____________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D)              (None, 5, 5, 64)                        0
# ____________________________________________________________________________________________________
# flatten_4 (Flatten)                          (None, 1600)                            0
# ____________________________________________________________________________________________________
# dense_13 (Dense)                             (None, 128)                             204928
# ____________________________________________________________________________________________________
# batch_normalization_9 (BatchNormalization)   (None, 128)                             512
# ____________________________________________________________________________________________________
# activation_9 (Activation)                    (None, 128)                             0
# ____________________________________________________________________________________________________
# dense_14 (Dense)                             (None, 10)                              1290
# ====================================================================================================
# Total params: 273,066
# Trainable params: 272,426
# Non-trainable params: 640
# ____________________________________________________________________________________________________

# %%
history = model.fit(X_train, y_train_c, batch_size=500, epochs=15, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/15
# 80/80 [==============================] - 3s 35ms/step - loss: 1.5672 - accuracy: 0.4378 - val_loss: 2.0525 - val_accuracy: 0.2891
# Epoch 2/15
# 80/80 [==============================] - 3s 34ms/step - loss: 1.1481 - accuracy: 0.5952 - val_loss: 1.5013 - val_accuracy: 0.4764
# Epoch 3/15
# 80/80 [==============================] - 2s 27ms/step - loss: 0.9780 - accuracy: 0.6601 - val_loss: 1.0536 - val_accuracy: 0.6266
# Epoch 4/15
# 80/80 [==============================] - 2s 26ms/step - loss: 0.8579 - accuracy: 0.7046 - val_loss: 1.1216 - val_accuracy: 0.6086
# Epoch 5/15
# 80/80 [==============================] - 2s 27ms/step - loss: 0.7684 - accuracy: 0.7373 - val_loss: 1.0692 - val_accuracy: 0.6206
# Epoch 6/15
# 80/80 [==============================] - 2s 29ms/step - loss: 0.6924 - accuracy: 0.7654 - val_loss: 0.9310 - val_accuracy: 0.6689
# Epoch 7/15
# 80/80 [==============================] - 2s 26ms/step - loss: 0.6241 - accuracy: 0.7900 - val_loss: 0.8756 - val_accuracy: 0.6928
# Epoch 8/15
# 80/80 [==============================] - 2s 27ms/step - loss: 0.5671 - accuracy: 0.8108 - val_loss: 0.8887 - val_accuracy: 0.6954
# Epoch 9/15
# 80/80 [==============================] - 3s 32ms/step - loss: 0.5091 - accuracy: 0.8340 - val_loss: 0.9083 - val_accuracy: 0.6875
# Epoch 10/15
# 80/80 [==============================] - 2s 31ms/step - loss: 0.4598 - accuracy: 0.8514 - val_loss: 0.8716 - val_accuracy: 0.6963
# Epoch 11/15
# 80/80 [==============================] - 2s 30ms/step - loss: 0.4093 - accuracy: 0.8717 - val_loss: 0.9602 - val_accuracy: 0.6876
# Epoch 12/15
# 80/80 [==============================] - 2s 29ms/step - loss: 0.3630 - accuracy: 0.8910 - val_loss: 0.9787 - val_accuracy: 0.6852
# Epoch 13/15
# 80/80 [==============================] - 2s 27ms/step - loss: 0.3203 - accuracy: 0.9048 - val_loss: 1.0222 - val_accuracy: 0.6796
# Epoch 14/15
# 80/80 [==============================] - 2s 27ms/step - loss: 0.2829 - accuracy: 0.9204 - val_loss: 0.8886 - val_accuracy: 0.7077
# Epoch 15/15
# 80/80 [==============================] - 2s 29ms/step - loss: 0.2432 - accuracy: 0.9374 - val_loss: 0.9723 - val_accuracy: 0.6899

# %%
score = model.evaluate(X_test, y_test_c, batch_size=128, verbose=0)

for i in range(len(score)):
    print("Test " + model.metrics_names[i] + " = %.3f" % score[i])
# Out:
# Test loss = 0.992
# Test accuracy = 0.687

# %%
PlotModelEval(model, history, X_test, y_test, cifar_labels)

# %% [markdown]
# #### **<span style="color:red">Question 10:</span>**
# Design and train a model that achieves at least 75% test accuracy in at most 25 epochs. Save the evaluation image for the report. Also, in the report you should explain your model and motivate the design choices you have made.

# %% [markdown]
# ### **Want some extra challenge?**
# For those of you that feel the competitive spark right now, we will hold an **optional** competition where you can submit your trained model-file for evaluation. To make this fair, you are not allowed to train for more than **50 epochs**, but other than that we want you to get creative. The competition is simple, we will evaluate all submitted models and the model with highest test accuracy wins. The prize is nothing less than eternal glory.
#
# Here are some things to look into, but note that we don't have the answers here. Any of these might improve the performance, or might not, or it might only work in combination with each other. This is up to you to figure out. This is how deep learning research often happens, trying things in a smart way to see what works best.
# * Tweak or change the optimizer or training parameters.
# * Tweak the filter parameters, such as numbers and sizes of filters.
# * Use other activation functions.
# * Add L1/L2 regularization (see https://www.tensorflow.org/api_docs/python/tf/keras/regularizers)
# * Include layers that we did not cover here (see https://www.tensorflow.org/api_docs/python/tf/keras/layers). For example, our best model uses the global pooling layers.
# * Take inspiration from some well-known architectures, such as ResNet or VGG16. (But don't just copy-paste those architectures. For one, what's the fun in that? Also, they take a long time to train, you will not have time.)
# * Use explicit model ensembing (training multiple models that vote on or average the outputs - this will also take a lot of time.)
# * Use data augmentation to create a larger training set (see https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator).
#
# Write your competition model here. This way you can try different things without deleting the model you created above. Also set the GroupName variable to your LiU IDs or some unique name; that way our scripts can be a lot easier, thanks and good luck :)

# %%
from tensorflow.keras.layers import GlobalAveragePooling2D
#from tensorflow.keras.optimizers import Adam

GroupName = "andhe794_matgr197"

x_in = Input(shape=X_train.shape[1:])

# Your code here
x = Conv2D(32, (3, 3), padding='same', activation='relu')(x_in)
x = Dropout(0.2)(x)

x = Conv2D(32, (3, 3), padding='same', activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2), padding='same')(x)

x = Conv2D(64, (3, 3), padding='same', activation='relu')(x)
x = Dropout(0.2)(x)

x = Conv2D(64, (3, 3), padding='same', activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2), padding='same')(x)

x = Conv2D(128, (3, 3), padding='same', activation='relu')(x)
x = Dropout(0.2)(x)

x = Conv2D(128, (3, 3), padding='same', activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2), padding='same')(x)

x = Flatten()(x)
x = Dropout(0.2)(x)

x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)

x = Dense(10, activation="softmax")(x)

model = Model(inputs=x_in, outputs=x, name=GroupName)

# You can also change this if you want
sgd = SGD(lr=0.005, decay=1e-6, momentum=0.9, nesterov=True)
# sgd = Adam(learning_rate=0.0095)
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=sgd)

# Print the summary and model image
model.summary(100)
# plot_model(model, show_shapes=True, show_layer_names=False)
# Out:
# Model: "andhe794_matgr197"
# ____________________________________________________________________________________________________
# Layer (type)                                 Output Shape                            Param #
# ====================================================================================================
# input_6 (InputLayer)                         [(None, 32, 32, 3)]                     0
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)                           (None, 32, 32, 32)                      896
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)                          (None, 32, 32, 32)                      0
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)                           (None, 32, 32, 32)                      9248
# ____________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D)              (None, 16, 16, 32)                      0
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)                           (None, 16, 16, 64)                      18496
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)                          (None, 16, 16, 64)                      0
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)                           (None, 16, 16, 64)                      36928
# ____________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D)              (None, 8, 8, 64)                        0
# ____________________________________________________________________________________________________
# conv2d_17 (Conv2D)                           (None, 8, 8, 128)                       73856
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)                          (None, 8, 8, 128)                       0
# ____________________________________________________________________________________________________
# conv2d_18 (Conv2D)                           (None, 8, 8, 128)                       147584
# ____________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D)              (None, 4, 4, 128)                       0
# ____________________________________________________________________________________________________
# flatten_5 (Flatten)                          (None, 2048)                            0
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)                          (None, 2048)                            0
# ____________________________________________________________________________________________________
# dense_15 (Dense)                             (None, 1024)                            2098176
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)                          (None, 1024)                            0
# ____________________________________________________________________________________________________
# dense_16 (Dense)                             (None, 10)                              10250
# ====================================================================================================
# Total params: 2,395,434
# Trainable params: 2,395,434
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
history = model.fit(X_train, y_train_c, batch_size=80, epochs=50, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/50
# 500/500 [==============================] - 5s 10ms/step - loss: 2.0391 - accuracy: 0.2479 - val_loss: 1.9221 - val_accuracy: 0.3144
# Epoch 2/50
# 500/500 [==============================] - 5s 10ms/step - loss: 1.6424 - accuracy: 0.4033 - val_loss: 1.5322 - val_accuracy: 0.4504
# Epoch 3/50
# 500/500 [==============================] - 5s 11ms/step - loss: 1.4648 - accuracy: 0.4702 - val_loss: 1.4060 - val_accuracy: 0.5013
# Epoch 4/50
# 500/500 [==============================] - 5s 10ms/step - loss: 1.3450 - accuracy: 0.5147 - val_loss: 1.3240 - val_accuracy: 0.5316
# Epoch 5/50
# 500/500 [==============================] - 5s 10ms/step - loss: 1.2450 - accuracy: 0.5542 - val_loss: 1.2044 - val_accuracy: 0.5835
# Epoch 6/50
# 500/500 [==============================] - 5s 11ms/step - loss: 1.1672 - accuracy: 0.5835 - val_loss: 1.1210 - val_accuracy: 0.6026
# Epoch 7/50
# 500/500 [==============================] - 5s 10ms/step - loss: 1.0928 - accuracy: 0.6106 - val_loss: 1.0399 - val_accuracy: 0.6328
# Epoch 8/50
# 500/500 [==============================] - 6s 11ms/step - loss: 1.0139 - accuracy: 0.6416 - val_loss: 0.9849 - val_accuracy: 0.6561
# Epoch 9/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.9561 - accuracy: 0.6592 - val_loss: 0.9368 - val_accuracy: 0.6735
# Epoch 10/50
# 500/500 [==============================] - 6s 12ms/step - loss: 0.8885 - accuracy: 0.6872 - val_loss: 0.8587 - val_accuracy: 0.7035
# Epoch 11/50
# 500/500 [==============================] - 5s 10ms/step - loss: 0.8339 - accuracy: 0.7058 - val_loss: 0.8337 - val_accuracy: 0.7117
# Epoch 12/50
# 500/500 [==============================] - 5s 10ms/step - loss: 0.7790 - accuracy: 0.7260 - val_loss: 0.8111 - val_accuracy: 0.7196
# Epoch 13/50
# 500/500 [==============================] - 5s 10ms/step - loss: 0.7256 - accuracy: 0.7458 - val_loss: 0.7659 - val_accuracy: 0.7354
# Epoch 14/50
# 500/500 [==============================] - 5s 10ms/step - loss: 0.6833 - accuracy: 0.7593 - val_loss: 0.7289 - val_accuracy: 0.7460
# Epoch 15/50
# 500/500 [==============================] - 4s 9ms/step - loss: 0.6350 - accuracy: 0.7776 - val_loss: 0.7146 - val_accuracy: 0.7507
# Epoch 16/50
# 500/500 [==============================] - 4s 9ms/step - loss: 0.5991 - accuracy: 0.7878 - val_loss: 0.7290 - val_accuracy: 0.7477
# Epoch 17/50
# 500/500 [==============================] - 5s 10ms/step - loss: 0.5593 - accuracy: 0.8025 - val_loss: 0.7045 - val_accuracy: 0.7589
# Epoch 18/50
# 500/500 [==============================] - 5s 11ms/step - loss: 0.5239 - accuracy: 0.8136 - val_loss: 0.6879 - val_accuracy: 0.7668
# Epoch 19/50
# 500/500 [==============================] - 5s 10ms/step - loss: 0.4892 - accuracy: 0.8263 - val_loss: 0.6869 - val_accuracy: 0.7674
# Epoch 20/50
# 500/500 [==============================] - 5s 10ms/step - loss: 0.4583 - accuracy: 0.8375 - val_loss: 0.6789 - val_accuracy: 0.7689
# Epoch 21/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.4276 - accuracy: 0.8501 - val_loss: 0.6941 - val_accuracy: 0.7696
# Epoch 22/50
# 500/500 [==============================] - 6s 11ms/step - loss: 0.4001 - accuracy: 0.8564 - val_loss: 0.6909 - val_accuracy: 0.7707
# Epoch 23/50
# 500/500 [==============================] - 5s 11ms/step - loss: 0.3700 - accuracy: 0.8677 - val_loss: 0.6933 - val_accuracy: 0.7707
# Epoch 24/50
# 500/500 [==============================] - 5s 10ms/step - loss: 0.3444 - accuracy: 0.8773 - val_loss: 0.6917 - val_accuracy: 0.7793
# Epoch 25/50
# 500/500 [==============================] - 5s 11ms/step - loss: 0.3251 - accuracy: 0.8831 - val_loss: 0.6780 - val_accuracy: 0.7791
# Epoch 26/50
# 500/500 [==============================] - 4s 9ms/step - loss: 0.3006 - accuracy: 0.8927 - val_loss: 0.7006 - val_accuracy: 0.7818
# Epoch 27/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.2861 - accuracy: 0.8966 - val_loss: 0.6995 - val_accuracy: 0.7792
# Epoch 28/50
# 500/500 [==============================] - 5s 10ms/step - loss: 0.2664 - accuracy: 0.9057 - val_loss: 0.7261 - val_accuracy: 0.7811
# Epoch 29/50
# 500/500 [==============================] - 5s 10ms/step - loss: 0.2478 - accuracy: 0.9115 - val_loss: 0.7373 - val_accuracy: 0.7784
# Epoch 30/50
# 500/500 [==============================] - 5s 10ms/step - loss: 0.2319 - accuracy: 0.9187 - val_loss: 0.7163 - val_accuracy: 0.7847
# Epoch 31/50
# 500/500 [==============================] - 5s 10ms/step - loss: 0.2226 - accuracy: 0.9188 - val_loss: 0.7226 - val_accuracy: 0.7893
# Epoch 32/50
# 500/500 [==============================] - 5s 10ms/step - loss: 0.2009 - accuracy: 0.9291 - val_loss: 0.7451 - val_accuracy: 0.7838
# Epoch 33/50
# 500/500 [==============================] - 5s 10ms/step - loss: 0.1901 - accuracy: 0.9328 - val_loss: 0.7684 - val_accuracy: 0.7891
# Epoch 34/50
# 500/500 [==============================] - 5s 10ms/step - loss: 0.1870 - accuracy: 0.9338 - val_loss: 0.7641 - val_accuracy: 0.7896
# Epoch 35/50
# 500/500 [==============================] - 4s 9ms/step - loss: 0.1746 - accuracy: 0.9382 - val_loss: 0.7686 - val_accuracy: 0.7881
# Epoch 36/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.1628 - accuracy: 0.9425 - val_loss: 0.8004 - val_accuracy: 0.7847
# Epoch 37/50
# 500/500 [==============================] - 4s 9ms/step - loss: 0.1545 - accuracy: 0.9452 - val_loss: 0.7749 - val_accuracy: 0.7882
# Epoch 38/50
# 500/500 [==============================] - 5s 10ms/step - loss: 0.1486 - accuracy: 0.9473 - val_loss: 0.7961 - val_accuracy: 0.7854
# Epoch 39/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.1442 - accuracy: 0.9484 - val_loss: 0.7663 - val_accuracy: 0.7906
# Epoch 40/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.1366 - accuracy: 0.9523 - val_loss: 0.8181 - val_accuracy: 0.7888
# Epoch 41/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.1318 - accuracy: 0.9535 - val_loss: 0.8252 - val_accuracy: 0.7913
# Epoch 42/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.1274 - accuracy: 0.9553 - val_loss: 0.8271 - val_accuracy: 0.7938
# Epoch 43/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.1207 - accuracy: 0.9567 - val_loss: 0.8539 - val_accuracy: 0.7904
# Epoch 44/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.1110 - accuracy: 0.9617 - val_loss: 0.8176 - val_accuracy: 0.7962
# Epoch 45/50
# 500/500 [==============================] - 5s 10ms/step - loss: 0.1110 - accuracy: 0.9599 - val_loss: 0.8408 - val_accuracy: 0.7916
# Epoch 46/50
# 500/500 [==============================] - 6s 11ms/step - loss: 0.1067 - accuracy: 0.9621 - val_loss: 0.8194 - val_accuracy: 0.7979
# Epoch 47/50
# 500/500 [==============================] - 6s 13ms/step - loss: 0.1037 - accuracy: 0.9640 - val_loss: 0.8316 - val_accuracy: 0.7986
# Epoch 48/50
# 500/500 [==============================] - 7s 13ms/step - loss: 0.1035 - accuracy: 0.9640 - val_loss: 0.8853 - val_accuracy: 0.7936
# Epoch 49/50
# 500/500 [==============================] - 6s 11ms/step - loss: 0.0940 - accuracy: 0.9671 - val_loss: 0.9064 - val_accuracy: 0.7957
# Epoch 50/50
# 500/500 [==============================] - 6s 12ms/step - loss: 0.0931 - accuracy: 0.9679 - val_loss: 0.8574 - val_accuracy: 0.7980

# %%
PlotModelEval(model, history, X_test, y_test, cifar_labels)

# %% [markdown]
# **Don't forget to save your model!**

# %%
model.save("CompetionModel_" + GroupName + ".h5")
