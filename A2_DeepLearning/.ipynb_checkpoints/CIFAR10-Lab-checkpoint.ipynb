# %%
import os
import tensorflow as tf

# If there are multiple GPUs and we only want to use one/some, set the number in the visible device list.
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# This sets the GPU to allocate memory only as needed
physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) != 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# ### **1. Loading the dataset**
# This assignment will focus on the CIFAR10 dataset. This is a collection of small images in 10 classes such as cars, cats, birds, etc. You can find more information here: https://www.cs.toronto.edu/~kriz/cifar.html. We start by loading and examining the data.

# %%
import numpy as np
from tensorflow.keras.datasets import cifar10

(X_train, y_train), (X_test, y_test) = cifar10.load_data()

print("Shape of training data:")
print(X_train.shape)
print(y_train.shape)
print("Shape of test data:")
print(X_test.shape)
print(y_test.shape)
# Out:
# Shape of training data:
# (50000, 32, 32, 3)
# (50000, 1)
# Shape of test data:
# (10000, 32, 32, 3)
# (10000, 1)

# %% [markdown]
# #### **<span style="color:red">Question 1:</span>**
# The shape of X_train and X_test has 4 values. What do each of these represent?

# %% [markdown]
# ##### **Plotting some images**
# This plots a random selection of images from each class. Rerun the cell to see a different selection.

# %%
from Custom import PlotRandomFromEachClass

cifar_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
PlotRandomFromEachClass(X_train, y_train, 3, labels=cifar_labels)

# %% [markdown]
# ##### **Preparing the dataset**
# Just like the MNIST dataset we normalize the images to [0,1] and transform the class indices to one-hot encoded vectors.

# %%
from tensorflow.keras.utils import to_categorical

# Transform label indices to one-hot encoded vectors
y_train_c = to_categorical(y_train, num_classes=10)
y_test_c  = to_categorical(y_test , num_classes=10)

# Normalization of pixel values (to [0-1] range)
X_train = X_train.astype('float32') / 255
X_test  = X_test.astype('float32')  / 255

# %% [markdown]
# ### **2. Fully connected classifier**
# We will start by creating a fully connected classifier using the ```Dense``` layer. We give you the first layer that flattens the image features to a single vector. Add the remaining layers to the network.
#
# Consider what the size of the output must be and what activation function you should use in the output layer.

# %%
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Flatten

x_in = Input(shape=X_train.shape[1:])
x = Flatten()(x_in)

# === Add your code here ===
x = Dense(64, activation="softplus")(x)
x = Dense(128, activation="softplus")(x)
x = Dense(32, activation="softplus")(x)
x = Dense(10, activation="softmax")(x)
# ==========================

model = Model(inputs=x_in, outputs=x)

# Now we build the model using Stochastic Gradient Descent with Nesterov momentum. We use accuracy as the metric.
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])
model.summary(100)
# Out:
# Model: "model"
# ____________________________________________________________________________________________________
# Layer (type)                                 Output Shape                            Param #
# ====================================================================================================
# input_1 (InputLayer)                         [(None, 32, 32, 3)]                     0
# ____________________________________________________________________________________________________
# flatten (Flatten)                            (None, 3072)                            0
# ____________________________________________________________________________________________________
# dense (Dense)                                (None, 64)                              196672
# ____________________________________________________________________________________________________
# dense_1 (Dense)                              (None, 128)                             8320
# ____________________________________________________________________________________________________
# dense_2 (Dense)                              (None, 32)                              4128
# ____________________________________________________________________________________________________
# dense_3 (Dense)                              (None, 10)                              330
# ====================================================================================================
# Total params: 209,450
# Trainable params: 209,450
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %% [markdown]
# ##### **Training the model**
# In order to show the differences between models in the first parts of the assignment, we will restrict the training to the following command using 15 epochs, batch size 32, and 20% validation data. From section 5 and forward you can change this as you please to increase the accuracy, but for now stick with this command.

# %%
history = model.fit(X_train,y_train_c, epochs=15, batch_size=32, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.8665 - accuracy: 0.3205 - val_loss: 1.7567 - val_accuracy: 0.3683
# Epoch 2/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.6786 - accuracy: 0.3974 - val_loss: 1.6601 - val_accuracy: 0.4122
# Epoch 3/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.5991 - accuracy: 0.4268 - val_loss: 1.5883 - val_accuracy: 0.4351
# Epoch 4/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.5430 - accuracy: 0.4471 - val_loss: 1.6157 - val_accuracy: 0.4201
# Epoch 5/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.5028 - accuracy: 0.4611 - val_loss: 1.5568 - val_accuracy: 0.4482
# Epoch 6/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.4630 - accuracy: 0.4710 - val_loss: 1.5293 - val_accuracy: 0.4649
# Epoch 7/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.4348 - accuracy: 0.4859 - val_loss: 1.4979 - val_accuracy: 0.4685
# Epoch 8/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.4070 - accuracy: 0.4945 - val_loss: 1.4685 - val_accuracy: 0.4773
# Epoch 9/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.3792 - accuracy: 0.5042 - val_loss: 1.4807 - val_accuracy: 0.4766
# Epoch 10/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.3581 - accuracy: 0.5123 - val_loss: 1.4718 - val_accuracy: 0.4770
# Epoch 11/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.3385 - accuracy: 0.5206 - val_loss: 1.4630 - val_accuracy: 0.4831
# Epoch 12/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.3175 - accuracy: 0.5259 - val_loss: 1.4739 - val_accuracy: 0.4743
# Epoch 13/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.2983 - accuracy: 0.5343 - val_loss: 1.4597 - val_accuracy: 0.4848
# Epoch 14/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.2785 - accuracy: 0.5360 - val_loss: 1.4431 - val_accuracy: 0.4919
# Epoch 15/15
# 1250/1250 [==============================] - 2s 2ms/step - loss: 1.2605 - accuracy: 0.5455 - val_loss: 1.4399 - val_accuracy: 0.4977

# %% [markdown]
# ##### **Evaluating the model**
# We use ```model.evaluate``` to get the loss and metric scores on the test data. To plot the results we give you a custom function that does the work for you.

# %%
score = model.evaluate(X_test, y_test_c, batch_size=128, verbose=0)

for i in range(len(score)):
    print("Test " + model.metrics_names[i] + " = %.3f" % score[i])
# Out:
# Test loss = 1.425
# Test accuracy = 0.499

# %%
from Custom import PlotModelEval

# Custom function for evaluating the model and plotting training history
PlotModelEval(model, history, X_test, y_test, cifar_labels)

# %% [markdown]
# #### **<span style="color:red">Question 2:</span>**
# Train a model that achieves above 45% accuracy on the test data. In the report, provide a (short) description of your model and show the evaluation image.

# %% [markdown]
# #### **<span style="color:red">Question 3:</span>**
# Compare this model to the one you used for the MNIST dataset in the first assignment, in terms of size and test accuracy. Why do you think this dataset is much harder to classify than the MNIST handwritten digits?

# %% [markdown]
# ### **3. CNN classifier**
# We will now move on to a network architecture that is more suited for this problem, the convolutional neural network. The new layers you will use are ```Conv2D``` and ```MaxPooling2D```, which you can find the documentation of here https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D and here https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D.

# %% [markdown]
# ##### **Creating the CNN model**
#
# A common way to build convolutional neural networks is to create blocks of layers of the form **[convolution - activation - pooling]**, and then stack several of these block to create the full convolution stack. This is often followed by a fully connected network to create the output classes. Use this recipe to build a CNN that acheives at least 62% accuracy on the test data.
#
# *Side note. Although this is a common way to build CNNs, it is be no means the only or even best way. It is a good starting point, but later in part 5 you might want to explore other architectures to acheive even better performance.*

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D

x_in = Input(shape=X_train.shape[1:])

# === Add your code here ===
x = Conv2D(32, (3, 3), activation="relu")(x_in)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Conv2D(64, (3, 3), activation="relu")(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Conv2D(128, (3, 3), activation="relu")(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Flatten()(x)
x = Dense(64, activation="softplus")(x)
x = Dense(32, activation="softplus")(x)
x = Dense(10, activation="softmax")(x)
# ==========================

model = Model(inputs=x_in, outputs=x)

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=sgd)
model.summary(100)
# Out:
# Model: "model_3"
# ____________________________________________________________________________________________________
# Layer (type)                                 Output Shape                            Param #
# ====================================================================================================
# input_4 (InputLayer)                         [(None, 32, 32, 3)]                     0
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                            (None, 30, 30, 32)                      896
# ____________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)               (None, 15, 15, 32)                      0
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                            (None, 13, 13, 64)                      18496
# ____________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)               (None, 6, 6, 64)                        0
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                            (None, 4, 4, 128)                       73856
# ____________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)               (None, 2, 2, 128)                       0
# ____________________________________________________________________________________________________
# flatten_2 (Flatten)                          (None, 512)                             0
# ____________________________________________________________________________________________________
# dense_7 (Dense)                              (None, 64)                              32832
# ____________________________________________________________________________________________________
# dense_8 (Dense)                              (None, 32)                              2080
# ____________________________________________________________________________________________________
# dense_9 (Dense)                              (None, 10)                              330
# ====================================================================================================
# Total params: 128,490
# Trainable params: 128,490
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %% [markdown]
# ##### **Training the CNN**

# %%
history = model.fit(X_train, y_train_c, batch_size=32, epochs=15, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.8419 - accuracy: 0.3104 - val_loss: 1.5631 - val_accuracy: 0.4391
# Epoch 2/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.3387 - accuracy: 0.5144 - val_loss: 1.2197 - val_accuracy: 0.5612s: 1.3535
# Epoch 3/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.1386 - accuracy: 0.5922 - val_loss: 1.0649 - val_accuracy: 0.6225
# Epoch 4/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.0065 - accuracy: 0.6481 - val_loss: 1.0173 - val_accuracy: 0.6526
# Epoch 5/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.8977 - accuracy: 0.6838 - val_loss: 0.9606 - val_accuracy: 0.6702
# Epoch 6/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.8108 - accuracy: 0.7154 - val_loss: 0.9166 - val_accuracy: 0.6806
# Epoch 7/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.7396 - accuracy: 0.7394 - val_loss: 0.9182 - val_accuracy: 0.6916
# Epoch 8/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.6752 - accuracy: 0.7616 - val_loss: 0.9497 - val_accuracy: 0.6814
# Epoch 9/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.6229 - accuracy: 0.7782 - val_loss: 0.9098 - val_accuracy: 0.6988
# Epoch 10/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.5707 - accuracy: 0.7978 - val_loss: 0.9073 - val_accuracy: 0.7022
# Epoch 11/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.5294 - accuracy: 0.8110 - val_loss: 0.9770 - val_accuracy: 0.6989
# Epoch 12/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 0.4922 - accuracy: 0.8257 - val_loss: 0.9609 - val_accuracy: 0.7008accuracy: 0.82
# Epoch 13/15
# 1250/1250 [==============================] - 4s 4ms/step - loss: 0.4591 - accuracy: 0.8385 - val_loss: 1.0290 - val_accuracy: 0.6955
# Epoch 14/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.4268 - accuracy: 0.8491 - val_loss: 1.0433 - val_accuracy: 0.6983
# Epoch 15/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.4009 - accuracy: 0.8598 - val_loss: 1.0893 - val_accuracy: 0.6970

# %% [markdown]
# ##### **Evaluating the CNN**

# %%
score = model.evaluate(X_test, y_test_c, batch_size=128, verbose=0)

for i in range(len(score)):
    print("Test " + model.metrics_names[i] + " = %.3f" % score[i])
# Out:
# Test loss = 1.113
# Test accuracy = 0.685

# %%
PlotModelEval(model, history, X_test, y_test, cifar_labels)

# %% [markdown]
# #### **<span style="color:red">Question 4:</span>**
# Train a model that achieves at least 62% test accuracy. In the report, provide a (short) description of your model and show the evaluation image.

# %% [markdown]
# #### **<span style="color:red">Question 5:</span>**
# Compare this model with the previous fully connected model. You should find that this one is much more efficient, i.e. achieves higher accuracy with fewer parameters. Explain in your own words how this is possible.

# %% [markdown]
# ### **4. Regularization**

# %% [markdown]
# #### **4.1 Dropout**
# You have probably seen that your CNN model overfits the training data. One way to prevent this is to add ```Dropout``` layers to the model, that randomly "drops" hidden nodes each training-iteration by setting their output to zero. Thus the model cannot rely on a small set of very good hidden features, but must instead learns to use different sets of hidden features each time. Dropout layers are usually added after the pooling layers in the convolution part of the model, or after activations in the fully connected part of the model.
#
# *Side note. In the next assignment you will work with Ensemble models, a way to use the output from several individual models to achieve higher performance than each model can achieve on its own. One way to interpret Dropout is that each random selection of nodes is a separate model that is trained only on the current iteration. The final output is then the average of outputs from all the individual models. In other words, Dropout can be seen as a way to build ensembling directly into the network, without having to train several models explicitly.*
#
# Extend your previous model with the Dropout layer and test the new performance.

# %%
from tensorflow.keras.layers import Dropout

x_in = Input(shape=X_train.shape[1:])

# === Add your code here ===
x = Conv2D(32, (3, 3), activation="relu")(x_in)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Conv2D(64, (3, 3), activation="relu")(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Conv2D(128, (3, 3), activation="relu")(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Dropout(0.2)(x)
x = Flatten()(x)
x = Dense(64, activation="softplus")(x)
x = Dense(32, activation="softplus")(x)
x = Dense(10, activation="softmax")(x)
# ==========================

model = Model(inputs=x_in, outputs=x)

# Compile model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=sgd)
model.summary(100)
# Out:
# Model: "model_8"
# ____________________________________________________________________________________________________
# Layer (type)                                 Output Shape                            Param #
# ====================================================================================================
# input_9 (InputLayer)                         [(None, 32, 32, 3)]                     0
# ____________________________________________________________________________________________________
# conv2d_18 (Conv2D)                           (None, 30, 30, 32)                      896
# ____________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D)              (None, 15, 15, 32)                      0
# ____________________________________________________________________________________________________
# conv2d_19 (Conv2D)                           (None, 13, 13, 64)                      18496
# ____________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D)              (None, 6, 6, 64)                        0
# ____________________________________________________________________________________________________
# conv2d_20 (Conv2D)                           (None, 4, 4, 128)                       73856
# ____________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D)              (None, 2, 2, 128)                       0
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)                          (None, 2, 2, 128)                       0
# ____________________________________________________________________________________________________
# flatten_7 (Flatten)                          (None, 512)                             0
# ____________________________________________________________________________________________________
# dense_22 (Dense)                             (None, 64)                              32832
# ____________________________________________________________________________________________________
# dense_23 (Dense)                             (None, 32)                              2080
# ____________________________________________________________________________________________________
# dense_24 (Dense)                             (None, 10)                              330
# ====================================================================================================
# Total params: 128,490
# Trainable params: 128,490
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
history = model.fit(X_train, y_train_c, batch_size=32, epochs=15, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.9080 - accuracy: 0.2826 - val_loss: 1.5508 - val_accuracy: 0.4220
# Epoch 2/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.4383 - accuracy: 0.4761 - val_loss: 1.3247 - val_accuracy: 0.5240
# Epoch 3/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.2388 - accuracy: 0.5529 - val_loss: 1.1565 - val_accuracy: 0.5893
# Epoch 4/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.1110 - accuracy: 0.5996 - val_loss: 1.0466 - val_accuracy: 0.6322
# Epoch 5/15
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.0220 - accuracy: 0.6364 - val_loss: 1.0000 - val_accuracy: 0.6535
# Epoch 6/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.9372 - accuracy: 0.6701 - val_loss: 0.9337 - val_accuracy: 0.6757
# Epoch 7/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.8738 - accuracy: 0.6927 - val_loss: 0.9611 - val_accuracy: 0.6626
# Epoch 8/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.8204 - accuracy: 0.7104 - val_loss: 0.9423 - val_accuracy: 0.6780racy
# Epoch 9/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.7721 - accuracy: 0.7282 - val_loss: 0.8497 - val_accuracy: 0.7077
# Epoch 10/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.7243 - accuracy: 0.7446 - val_loss: 0.8493 - val_accuracy: 0.7149
# Epoch 11/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.6950 - accuracy: 0.7551 - val_loss: 0.8468 - val_accuracy: 0.7101
# Epoch 12/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.6535 - accuracy: 0.7674 - val_loss: 0.8429 - val_accuracy: 0.7139
# Epoch 13/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.6227 - accuracy: 0.7802 - val_loss: 0.8296 - val_accuracy: 0.7191
# Epoch 14/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.5960 - accuracy: 0.7893 - val_loss: 0.8584 - val_accuracy: 0.7215
# Epoch 15/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.5738 - accuracy: 0.7973 - val_loss: 0.8606 - val_accuracy: 0.7200

# %%
score = model.evaluate(X_test, y_test_c, batch_size=128, verbose=0)

for i in range(len(score)):
    print("Test " + model.metrics_names[i] + " = %.3f" % score[i])
# Out:
# Test loss = 0.855
# Test accuracy = 0.716

# %%
PlotModelEval(model, history, X_test, y_test, cifar_labels)

# %% [markdown]
# #### **<span style="color:red">Question 6:</span>**
# Train the modified CNN-model. Save the evaluation image for the report.

# %% [markdown]
# #### **<span style="color:red">Question 7:</span>**
# Compare this model and the previous in terms of the training accuracy, validation accuracy, and test accuracy. Explain the similarities and differences (remember that the only difference between the models should be the addition of Dropout layers).
#
# Hint: what does the dropout layer do at test time?

# %% [markdown]
# #### **4.2 Batch normalization**
# The final layer we will explore is ```BatchNormalization```. As the name suggests, this layer normalizes the data in each batch to have a specific mean and standard deviation, which is learned during training. The reason for this is quite complicated (and still debated among the experts), but suffice to say that it helps the optimization converge faster which means we get higher performance in fewer epochs. The normalization is done separatly for each feature, i.e. the statistics are calculated accross the batch dimension of the input data. The equations for batch-normalizing one feature are the following, where $N$ is the batch size, $x$ the input features, and $y$ the normalized output features:
#
# $$ \mu = \frac{1}{N} \sum_{i=0}^{N}x_i,\;\;\;\; \sigma^2 = \frac{1}{N} \sum_{i=0}^{N}(x_i - \mu)^2 $$
#
# $$ \hat{x}_i = \frac{x_i - \mu}{\sqrt{\sigma^2 + \epsilon}} $$
#
# $$ y_i = \gamma \hat{x}_i + \beta $$
#
# At first glance this might look intimidating, but all it means is that we begin by scaling and shifting the data to have mean $\mu=0$ and standard deviation $\sigma=1$. After this we use the learnable parameters $\gamma$ and $\beta$ to decide the width and center of the final distribution. $\epsilon$ is a small constant value that prevents the denominator from being zero.
#
# In addition to learning the parameters $\gamma$ and $\beta$ by gradient decent just like the weights, Batch Normalization also keeps track of the running average of minibatch statistics $\mu$ and $\sigma$. These averages are used to normalize the test data. We can tune the rate at which the running averages are updated with the *momentum* parameter of the BatchNormalization layer. A large momentum means that the statistics converge more slowly and therefore requires more updates before it represents the data. A low momentum, on the other hand, adapts to the data more quickly but might lead to unstable behaviour if the latest minibatches are not representative of the whole dataset. For this test we recommend a momentum of 0.75, but you probably want to change this when you design a larger network in Section 5.
#
# The batch normalization layer should be added after the hidden layer linear transformation, but before the nonlinear activation. This means that we cannot specify the activation funciton in the ```Conv2D``` or ```Dense``` if we want to batch-normalize the output. We therefore need to use the ```Activation``` layer to add a separate activation to the network stack after batch normalization. For example, the convolution block will now look like **[conv - batchnorm - activation - pooling]**.
#
# Extend your previous model with batch normalization, both in the convolution and fully connected part of the model.

# %%
from tensorflow.keras.layers import BatchNormalization, Activation

x_in = Input(shape=X_train.shape[1:])

# === Add your code here ===
x = Conv2D(32, (3, 3))(x_in)
x = BatchNormalization(momentum=0.75)(x)
x = Activation("softplus")(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

x = Conv2D(64, (3, 3))(x)
x = BatchNormalization(momentum=0.75)(x)
x = Activation("softplus")(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

x = Conv2D(128, (3, 3))(x)
x = BatchNormalization(momentum=0.75)(x)
x = Activation("softplus")(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

x = Flatten()(x)

x = Dense(64)(x)
x = BatchNormalization(momentum=0.75)(x)
x = Activation("softplus")(x)

x = Dense(32)(x)
x = BatchNormalization(momentum=0.75)(x)
x = Activation("softplus")(x)

x = Dense(10, activation="softmax")(x)
# ==========================

model = Model(inputs=x_in, outputs=x)

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=sgd)
model.summary(100)
# Out:
# Model: "model_12"
# ____________________________________________________________________________________________________
# Layer (type)                                 Output Shape                            Param #
# ====================================================================================================
# input_14 (InputLayer)                        [(None, 32, 32, 3)]                     0
# ____________________________________________________________________________________________________
# conv2d_31 (Conv2D)                           (None, 30, 30, 32)                      896
# ____________________________________________________________________________________________________
# batch_normalization_16 (BatchNormalization)  (None, 30, 30, 32)                      128
# ____________________________________________________________________________________________________
# activation_13 (Activation)                   (None, 30, 30, 32)                      0
# ____________________________________________________________________________________________________
# max_pooling2d_30 (MaxPooling2D)              (None, 15, 15, 32)                      0
# ____________________________________________________________________________________________________
# conv2d_32 (Conv2D)                           (None, 13, 13, 64)                      18496
# ____________________________________________________________________________________________________
# batch_normalization_17 (BatchNormalization)  (None, 13, 13, 64)                      256
# ____________________________________________________________________________________________________
# activation_14 (Activation)                   (None, 13, 13, 64)                      0
# ____________________________________________________________________________________________________
# max_pooling2d_31 (MaxPooling2D)              (None, 6, 6, 64)                        0
# ____________________________________________________________________________________________________
# conv2d_33 (Conv2D)                           (None, 4, 4, 128)                       73856
# ____________________________________________________________________________________________________
# batch_normalization_18 (BatchNormalization)  (None, 4, 4, 128)                       512
# ____________________________________________________________________________________________________
# activation_15 (Activation)                   (None, 4, 4, 128)                       0
# ____________________________________________________________________________________________________
# max_pooling2d_32 (MaxPooling2D)              (None, 2, 2, 128)                       0
# ____________________________________________________________________________________________________
# flatten_11 (Flatten)                         (None, 512)                             0
# ____________________________________________________________________________________________________
# dense_34 (Dense)                             (None, 64)                              32832
# ____________________________________________________________________________________________________
# batch_normalization_19 (BatchNormalization)  (None, 64)                              256
# ____________________________________________________________________________________________________
# activation_16 (Activation)                   (None, 64)                              0
# ____________________________________________________________________________________________________
# dense_35 (Dense)                             (None, 32)                              2080
# ____________________________________________________________________________________________________
# batch_normalization_20 (BatchNormalization)  (None, 32)                              128
# ____________________________________________________________________________________________________
# activation_17 (Activation)                   (None, 32)                              0
# ____________________________________________________________________________________________________
# dense_36 (Dense)                             (None, 10)                              330
# ====================================================================================================
# Total params: 129,770
# Trainable params: 129,130
# Non-trainable params: 640
# ____________________________________________________________________________________________________

# %%
history = model.fit(X_train, y_train_c, batch_size=32, epochs=15, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/15
# 1250/1250 [==============================] - 5s 4ms/step - loss: 0.4232 - accuracy: 0.8509 - val_loss: 0.9758 - val_accuracy: 0.7070
# Epoch 2/15
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.3934 - accuracy: 0.8608 - val_loss: 1.1147 - val_accuracy: 0.6967
# Epoch 3/15
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.3586 - accuracy: 0.8741 - val_loss: 1.0504 - val_accuracy: 0.7091
# Epoch 4/15
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.3362 - accuracy: 0.8820 - val_loss: 0.9673 - val_accuracy: 0.7254
# Epoch 5/15
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.3024 - accuracy: 0.8927 - val_loss: 1.0355 - val_accuracy: 0.7187
# Epoch 6/15
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.2874 - accuracy: 0.8984 - val_loss: 1.0882 - val_accuracy: 0.7196
# Epoch 7/15
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.2644 - accuracy: 0.9063 - val_loss: 1.1560 - val_accuracy: 0.7085
# Epoch 8/15
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.2411 - accuracy: 0.9158 - val_loss: 1.1456 - val_accuracy: 0.7226
# Epoch 9/15
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.2324 - accuracy: 0.9182 - val_loss: 1.1064 - val_accuracy: 0.7213
# Epoch 10/15
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.2068 - accuracy: 0.9269 - val_loss: 1.1473 - val_accuracy: 0.7254
# Epoch 11/15
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.1985 - accuracy: 0.9306 - val_loss: 1.2286 - val_accuracy: 0.7135
# Epoch 12/15
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.1852 - accuracy: 0.9348 - val_loss: 1.2669 - val_accuracy: 0.7100
# Epoch 13/15
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.1826 - accuracy: 0.9344 - val_loss: 1.3724 - val_accuracy: 0.7061
# Epoch 14/15
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.1689 - accuracy: 0.9396 - val_loss: 1.3088 - val_accuracy: 0.7175
# Epoch 15/15
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.1520 - accuracy: 0.9465 - val_loss: 1.3239 - val_accuracy: 0.7196

# %%
score = model.evaluate(X_test, y_test_c, batch_size=128, verbose=0)

for i in range(len(score)):
    print("Test " + model.metrics_names[i] + " = %.3f" % score[i])
# Out:
# Test loss = 1.346
# Test accuracy = 0.720

# %%
PlotModelEval(model, history, X_test, y_test, cifar_labels)

# %% [markdown]
# #### **<span style="color:red">Question 8:</span>**
# Train the model and save the evaluation image for the report.

# %% [markdown]
# #### **<span style="color:red">Question 9:</span>**
# When using BatchNorm one must take care to select a good minibatch size. Describe what problems might arise if the wrong minibatch size is used.
#
# You can reason about this given the description of BatchNorm above, or you can search for the information in other sources. Do not forget to provide links to the sources if you do!

# %% [markdown]
# ### **5. Putting it all together**
# We now want you to create your own model based on what you have learned. We want you to experiment and see what works and what doesn't, so don't go crazy with the number of epochs until you think you have something that works.
#
# To pass this assignment, we want you to acheive **75%** accuracy on the test data in no more than **25 epochs**. This is possible using the layers and techniques we have explored in this notebook, but you are free to use any other methods that we didn't cover. (You are obviously not allowed to cheat, for example by training on the test data.)

# %%
from tensorflow.keras.utils import plot_model

x_in = Input(shape=X_train.shape[1:])

# === Add your code here ===
x = Conv2D(32, (3, 3))(x_in)
x = BatchNormalization(momentum=0.95)(x)
x = Activation("relu")(x)

x = Conv2D(32, (3, 3))(x)
x = BatchNormalization(momentum=0.95)(x)
x = Activation("relu")(x)

x = MaxPooling2D(pool_size=(2, 2))(x)

x = Conv2D(64, (3, 3))(x)
x = BatchNormalization(momentum=0.95)(x)
x = Activation("relu")(x)

x = Conv2D(64, (3, 3))(x)
x = BatchNormalization(momentum=0.95)(x)
x = Activation("relu")(x)

x = MaxPooling2D(pool_size=(2, 2))(x)

x = Flatten()(x)

x = Dense(128)(x)
x = BatchNormalization(momentum=0.95)(x)
x = Activation("relu")(x)

x = Dense(10, activation="softmax")(x)
# ==========================

model = Model(inputs=x_in, outputs=x)

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=sgd)
model.summary(100)
plot_model(model, show_shapes=True, show_layer_names=False)
# Out:
# Model: "model_21"
# ____________________________________________________________________________________________________
# Layer (type)                                 Output Shape                            Param #
# ====================================================================================================
# input_25 (InputLayer)                        [(None, 32, 32, 3)]                     0
# ____________________________________________________________________________________________________
# conv2d_62 (Conv2D)                           (None, 30, 30, 32)                      896
# ____________________________________________________________________________________________________
# batch_normalization_59 (BatchNormalization)  (None, 30, 30, 32)                      128
# ____________________________________________________________________________________________________
# activation_56 (Activation)                   (None, 30, 30, 32)                      0
# ____________________________________________________________________________________________________
# conv2d_63 (Conv2D)                           (None, 28, 28, 32)                      9248
# ____________________________________________________________________________________________________
# batch_normalization_60 (BatchNormalization)  (None, 28, 28, 32)                      128
# ____________________________________________________________________________________________________
# activation_57 (Activation)                   (None, 28, 28, 32)                      0
# ____________________________________________________________________________________________________
# max_pooling2d_53 (MaxPooling2D)              (None, 14, 14, 32)                      0
# ____________________________________________________________________________________________________
# conv2d_64 (Conv2D)                           (None, 12, 12, 64)                      18496
# ____________________________________________________________________________________________________
# batch_normalization_61 (BatchNormalization)  (None, 12, 12, 64)                      256
# ____________________________________________________________________________________________________
# activation_58 (Activation)                   (None, 12, 12, 64)                      0
# ____________________________________________________________________________________________________
# conv2d_65 (Conv2D)                           (None, 10, 10, 64)                      36928
# ____________________________________________________________________________________________________
# batch_normalization_62 (BatchNormalization)  (None, 10, 10, 64)                      256
# ____________________________________________________________________________________________________
# activation_59 (Activation)                   (None, 10, 10, 64)                      0
# ____________________________________________________________________________________________________
# max_pooling2d_54 (MaxPooling2D)              (None, 5, 5, 64)                        0
# ____________________________________________________________________________________________________
# flatten_22 (Flatten)                         (None, 1600)                            0
# ____________________________________________________________________________________________________
# dense_57 (Dense)                             (None, 128)                             204928
# ____________________________________________________________________________________________________
# batch_normalization_63 (BatchNormalization)  (None, 128)                             512
# ____________________________________________________________________________________________________
# activation_60 (Activation)                   (None, 128)                             0
# ____________________________________________________________________________________________________
# dense_58 (Dense)                             (None, 10)                              1290
# ====================================================================================================
# Total params: 273,066
# Trainable params: 272,426
# Non-trainable params: 640
# ____________________________________________________________________________________________________

# %%
history = model.fit(X_train, y_train_c, batch_size=500, epochs=15, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/15
# 80/80 [==============================] - 3s 39ms/step - loss: 0.0652 - accuracy: 0.9833 - val_loss: 0.8021 - val_accuracy: 0.7842
# Epoch 2/15
# 80/80 [==============================] - 3s 33ms/step - loss: 0.0468 - accuracy: 0.9912 - val_loss: 0.7905 - val_accuracy: 0.7875
# Epoch 3/15
# 80/80 [==============================] - 3s 33ms/step - loss: 0.0397 - accuracy: 0.9934 - val_loss: 0.7872 - val_accuracy: 0.7884
# Epoch 4/15
# 80/80 [==============================] - 3s 34ms/step - loss: 0.0350 - accuracy: 0.9951 - val_loss: 0.7875 - val_accuracy: 0.7894
# Epoch 5/15
# 80/80 [==============================] - 3s 33ms/step - loss: 0.0316 - accuracy: 0.9961 - val_loss: 0.7902 - val_accuracy: 0.7902
# Epoch 6/15
# 80/80 [==============================] - 3s 34ms/step - loss: 0.0291 - accuracy: 0.9970 - val_loss: 0.7907 - val_accuracy: 0.7917
# Epoch 7/15
# 80/80 [==============================] - 3s 33ms/step - loss: 0.0269 - accuracy: 0.9976 - val_loss: 0.7947 - val_accuracy: 0.7932
# Epoch 8/15
# 80/80 [==============================] - 3s 33ms/step - loss: 0.0250 - accuracy: 0.9980 - val_loss: 0.7962 - val_accuracy: 0.7923
# Epoch 9/15
# 80/80 [==============================] - 3s 35ms/step - loss: 0.0234 - accuracy: 0.9984 - val_loss: 0.7986 - val_accuracy: 0.7932
# Epoch 10/15
# 80/80 [==============================] - 3s 34ms/step - loss: 0.0218 - accuracy: 0.9988 - val_loss: 0.8020 - val_accuracy: 0.7923
# Epoch 11/15
# 80/80 [==============================] - 3s 34ms/step - loss: 0.0207 - accuracy: 0.9991 - val_loss: 0.8046 - val_accuracy: 0.7924
# Epoch 12/15
# 80/80 [==============================] - 3s 34ms/step - loss: 0.0195 - accuracy: 0.9991 - val_loss: 0.8078 - val_accuracy: 0.7930
# Epoch 13/15
# 80/80 [==============================] - 3s 35ms/step - loss: 0.0185 - accuracy: 0.9993 - val_loss: 0.8102 - val_accuracy: 0.7939
# Epoch 14/15
# 80/80 [==============================] - 3s 34ms/step - loss: 0.0177 - accuracy: 0.9994 - val_loss: 0.8145 - val_accuracy: 0.7929
# Epoch 15/15
# 80/80 [==============================] - 3s 34ms/step - loss: 0.0168 - accuracy: 0.9993 - val_loss: 0.8182 - val_accuracy: 0.7933

# %%
score = model.evaluate(X_test, y_test_c, batch_size=128, verbose=0)

for i in range(len(score)):
    print("Test " + model.metrics_names[i] + " = %.3f" % score[i])
# Out:
# Test loss = 0.850
# Test accuracy = 0.782

# %%
PlotModelEval(model, history, X_test, y_test, cifar_labels)

# %% [markdown]
# #### **<span style="color:red">Question 10:</span>**
# Design and train a model that achieves at least 75% test accuracy in at most 25 epochs. Save the evaluation image for the report. Also, in the report you should explain your model and motivate the design choices you have made.

# %% [markdown]
# ### **Want some extra challenge?**
# For those of you that feel the competitive spark right now, we will hold an **optional** competition where you can submit your trained model-file for evaluation. To make this fair, you are not allowed to train for more than **50 epochs**, but other than that we want you to get creative. The competition is simple, we will evaluate all submitted models and the model with highest test accuracy wins. The prize is nothing less than eternal glory.
#
# Here are some things to look into, but note that we don't have the answers here. Any of these might improve the performance, or might not, or it might only work in combination with each other. This is up to you to figure out. This is how deep learning research often happens, trying things in a smart way to see what works best.
# * Tweak or change the optimizer or training parameters.
# * Tweak the filter parameters, such as numbers and sizes of filters.
# * Use other activation functions.
# * Add L1/L2 regularization (see https://www.tensorflow.org/api_docs/python/tf/keras/regularizers)
# * Include layers that we did not cover here (see https://www.tensorflow.org/api_docs/python/tf/keras/layers). For example, our best model uses the global pooling layers.
# * Take inspiration from some well-known architectures, such as ResNet or VGG16. (But don't just copy-paste those architectures. For one, what's the fun in that? Also, they take a long time to train, you will not have time.)
# * Use explicit model ensembing (training multiple models that vote on or average the outputs - this will also take a lot of time.)
# * Use data augmentation to create a larger training set (see https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator).
#
# Write your competition model here. This way you can try different things without deleting the model you created above. Also set the GroupName variable to your LiU IDs or some unique name; that way our scripts can be a lot easier, thanks and good luck :)

# %%
from tensorflow.keras.layers import GlobalAveragePooling2D
#from tensorflow.keras.optimizers import Adam

GroupName = "andhe794_matgr197"

x_in = Input(shape=X_train.shape[1:])

# Your code here
x = Conv2D(32, (3, 3), padding='same', activation='relu')(x_in)
x = Dropout(0.2)(x)

x = Conv2D(32, (3, 3), padding='same', activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2), padding='same')(x)

x = Conv2D(64, (3, 3), padding='same', activation='relu')(x)
x = Dropout(0.2)(x)

x = Conv2D(64, (3, 3), padding='same', activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2), padding='same')(x)

x = Conv2D(128, (3, 3), padding='same', activation='relu')(x)
x = Dropout(0.2)(x)

x = Conv2D(128, (3, 3), padding='same', activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2), padding='same')(x)

x = Flatten()(x)
x = Dropout(0.2)(x)

x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)

x = Dense(10, activation="softmax")(x)

model = Model(inputs=x_in, outputs=x, name=GroupName)

# You can also change this if you want
sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
# sgd = Adam(learning_rate=0.0095)
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=sgd)

# Print the summary and model image
model.summary(100)
# plot_model(model, show_shapes=True, show_layer_names=False)
# Out:
# -----------------------------------------------------------------
# ImportError                     Traceback (most recent call last)
# <ipython-input-203-3ea6d0ad7274> in <module>
#       1 from tensorflow.keras.layers import GlobalAveragePooling2D
#       2 #from tensorflow.keras.optimizers import Adam
# ----> 3 from tensorflow.keras.constraints import maxnorm
#       4
#       5 GroupName = "andhe794_matgr197"
#
# ImportError: cannot import name 'maxnorm' from 'tensorflow.keras.constraints' (C:\Users\Andreas\AppData\Roaming\Python\Python38\site-packages\tensorflow\keras\constraints\__init__.py)

# %%
history = model.fit(X_train, y_train_c, batch_size=80, epochs=50, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/50
# 500/500 [==============================] - 8s 15ms/step - loss: 1.4694 - accuracy: 0.4771 - val_loss: 2.0378 - val_accuracy: 0.3338
# Epoch 2/50
# 500/500 [==============================] - 7s 15ms/step - loss: 1.1142 - accuracy: 0.6076 - val_loss: 1.1416 - val_accuracy: 0.5973
# Epoch 3/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.9698 - accuracy: 0.6603 - val_loss: 1.0389 - val_accuracy: 0.6417
# Epoch 4/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.8718 - accuracy: 0.6963 - val_loss: 1.0314 - val_accuracy: 0.6373
# Epoch 5/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.7989 - accuracy: 0.7262 - val_loss: 0.9146 - val_accuracy: 0.6762
# Epoch 6/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.7370 - accuracy: 0.7467 - val_loss: 0.9196 - val_accuracy: 0.6799
# Epoch 7/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.6884 - accuracy: 0.7638 - val_loss: 0.8990 - val_accuracy: 0.6878
# Epoch 8/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.6368 - accuracy: 0.7846 - val_loss: 1.0566 - val_accuracy: 0.6386
# Epoch 9/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.5949 - accuracy: 0.7992 - val_loss: 0.9382 - val_accuracy: 0.6792
# Epoch 10/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.5506 - accuracy: 0.8164 - val_loss: 0.8951 - val_accuracy: 0.6929
# Epoch 11/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.5140 - accuracy: 0.8309 - val_loss: 0.9060 - val_accuracy: 0.6860
# Epoch 12/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.4790 - accuracy: 0.8437 - val_loss: 0.8724 - val_accuracy: 0.7029
# Epoch 13/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.4468 - accuracy: 0.8556 - val_loss: 0.9412 - val_accuracy: 0.6823
# Epoch 14/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.4218 - accuracy: 0.8634 - val_loss: 1.0225 - val_accuracy: 0.6672
# Epoch 15/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.3892 - accuracy: 0.8757 - val_loss: 0.8420 - val_accuracy: 0.7140
# Epoch 16/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.3584 - accuracy: 0.8888 - val_loss: 0.8714 - val_accuracy: 0.7101
# Epoch 17/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.3351 - accuracy: 0.8976 - val_loss: 0.9194 - val_accuracy: 0.6899
# Epoch 18/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.3118 - accuracy: 0.9046 - val_loss: 0.8290 - val_accuracy: 0.7223
# Epoch 19/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.2925 - accuracy: 0.9111 - val_loss: 0.8392 - val_accuracy: 0.7235
# Epoch 20/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.2695 - accuracy: 0.9211 - val_loss: 0.8755 - val_accuracy: 0.7109
# Epoch 21/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.2524 - accuracy: 0.9284 - val_loss: 0.9349 - val_accuracy: 0.7038
# Epoch 22/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.2341 - accuracy: 0.9347 - val_loss: 0.8851 - val_accuracy: 0.7152
# Epoch 23/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.2185 - accuracy: 0.9390 - val_loss: 0.8264 - val_accuracy: 0.7273
# Epoch 24/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.2011 - accuracy: 0.9468 - val_loss: 0.8403 - val_accuracy: 0.7292
# Epoch 25/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.1938 - accuracy: 0.9478 - val_loss: 0.9107 - val_accuracy: 0.7112
# Epoch 26/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.1800 - accuracy: 0.9514 - val_loss: 0.8232 - val_accuracy: 0.7322
# Epoch 27/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.1685 - accuracy: 0.9558 - val_loss: 0.8219 - val_accuracy: 0.7371
# Epoch 28/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.1585 - accuracy: 0.9593 - val_loss: 0.9195 - val_accuracy: 0.7171
# Epoch 29/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.1447 - accuracy: 0.9640 - val_loss: 0.8113 - val_accuracy: 0.7459
# Epoch 30/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.1389 - accuracy: 0.9658 - val_loss: 0.8590 - val_accuracy: 0.7338
# Epoch 31/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.1315 - accuracy: 0.9682 - val_loss: 0.8569 - val_accuracy: 0.7360
# Epoch 32/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.1204 - accuracy: 0.9726 - val_loss: 0.8800 - val_accuracy: 0.7298
# Epoch 33/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.1156 - accuracy: 0.9731 - val_loss: 0.8294 - val_accuracy: 0.7357
# Epoch 34/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.1100 - accuracy: 0.9755 - val_loss: 0.8887 - val_accuracy: 0.7266
# Epoch 35/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.1041 - accuracy: 0.9761 - val_loss: 0.8600 - val_accuracy: 0.7343
# Epoch 36/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.0999 - accuracy: 0.9785 - val_loss: 0.8581 - val_accuracy: 0.7414
# Epoch 37/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.0966 - accuracy: 0.9781 - val_loss: 0.9049 - val_accuracy: 0.7322
# Epoch 38/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.0902 - accuracy: 0.9809 - val_loss: 0.8466 - val_accuracy: 0.7443
# Epoch 39/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.0845 - accuracy: 0.9829 - val_loss: 0.8394 - val_accuracy: 0.7441
# Epoch 40/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.0800 - accuracy: 0.9837 - val_loss: 0.8913 - val_accuracy: 0.7367
# Epoch 41/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.0769 - accuracy: 0.9847 - val_loss: 0.9471 - val_accuracy: 0.7226
# Epoch 42/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.0755 - accuracy: 0.9838 - val_loss: 0.9408 - val_accuracy: 0.7234
# Epoch 43/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.0720 - accuracy: 0.9853 - val_loss: 0.8613 - val_accuracy: 0.7445
# Epoch 44/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.0666 - accuracy: 0.9875 - val_loss: 0.8619 - val_accuracy: 0.7441
# Epoch 45/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.0662 - accuracy: 0.9869 - val_loss: 0.8698 - val_accuracy: 0.7438
# Epoch 46/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.0629 - accuracy: 0.9884 - val_loss: 0.9029 - val_accuracy: 0.7360
# Epoch 47/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.0595 - accuracy: 0.9895 - val_loss: 0.8814 - val_accuracy: 0.7407
# Epoch 48/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.0572 - accuracy: 0.9900 - val_loss: 0.8446 - val_accuracy: 0.7543
# Epoch 49/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.0552 - accuracy: 0.9904 - val_loss: 0.8705 - val_accuracy: 0.7507
# Epoch 50/50
# 500/500 [==============================] - 8s 15ms/step - loss: 0.0532 - accuracy: 0.9905 - val_loss: 0.8916 - val_accuracy: 0.7476

# %%
PlotModelEval(model, history, X_test, y_test, cifar_labels)

# %% [markdown]
# **Don't forget to save your model!**

# %%
model.save("CompetionModel_" + GroupName + ".h5")
